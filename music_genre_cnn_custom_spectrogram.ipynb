# %% [markdown]
# This file is the code for training the custom spectrograms using the custom-built CNN. **For a step-by-step explanation, please move to music_genre_cnn_melody_spectrogram.ipynb. (Since the code is similar!)\**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import sklearn.metrics as skm
import sklearn.model_selection as skms
import sklearn.preprocessing as skp
import random
import librosa, IPython
import librosa.display as lplt
import os
seed = 12
np.random.seed(seed)

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams['font.size'] = 12

# %%
competition_name = "andradaolteanu/gtzan-dataset-music-genre-classification"

# Mount your Google Drive.
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
kaggle_creds_path = "/content/drive/MyDrive/kaggle.json"

! pip install kaggle --quiet

# %%
! mkdir ~/.kaggle
! cp {kaggle_creds_path} ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d {competition_name}

competition_name1 = "gtzan-dataset-music-genre-classification"
! mkdir kaggle_data
! unzip {competition_name1 + ".zip"} -d kaggle_data

# Unmount your Google Drive
drive.flush_and_unmount()
# Out:
# Downloading gtzan-dataset-music-genre-classification.zip to /content
# 100% 1.21G/1.21G [00:59<00:00, 21.7MB/s]
# 100% 1.21G/1.21G [00:59<00:00, 21.8MB/s]
# Archive:  gtzan-dataset-music-genre-classification.zip
#   inflating: kaggle_data/Data/features_30_sec.csv
#   inflating: kaggle_data/Data/features_3_sec.csv
#   inflating: kaggle_data/Data/genres_original/blues/blues.00000.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00001.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00002.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00003.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00004.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00005.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00006.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00007.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00008.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00009.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00010.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00011.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00012.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00013.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00014.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00015.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00016.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00017.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00018.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00019.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00020.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00021.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00022.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00023.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00024.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00025.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00026.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00027.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00028.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00029.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00030.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00031.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00032.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00033.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00034.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00035.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00036.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00037.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00038.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00039.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00040.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00041.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00042.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00043.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00044.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00045.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00046.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00047.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00048.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00049.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00050.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00051.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00052.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00053.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00054.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00055.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00056.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00057.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00058.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00059.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00060.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00061.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00062.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00063.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00064.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00065.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00066.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00067.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00068.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00069.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00070.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00071.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00072.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00073.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00074.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00075.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00076.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00077.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00078.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00079.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00080.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00081.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00082.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00083.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00084.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00085.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00086.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00087.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00088.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00089.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00090.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00091.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00092.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00093.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00094.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00095.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00096.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00097.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00098.wav
#   inflating: kaggle_data/Data/genres_original/blues/blues.00099.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00000.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00001.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00002.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00003.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00004.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00005.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00006.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00007.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00008.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00009.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00010.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00011.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00012.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00013.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00014.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00015.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00016.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00017.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00018.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00019.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00020.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00021.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00022.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00023.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00024.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00025.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00026.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00027.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00028.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00029.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00030.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00031.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00032.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00033.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00034.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00035.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00036.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00037.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00038.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00039.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00040.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00041.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00042.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00043.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00044.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00045.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00046.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00047.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00048.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00049.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00050.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00051.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00052.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00053.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00054.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00055.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00056.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00057.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00058.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00059.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00060.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00061.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00062.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00063.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00064.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00065.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00066.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00067.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00068.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00069.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00070.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00071.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00072.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00073.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00074.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00075.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00076.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00077.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00078.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00079.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00080.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00081.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00082.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00083.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00084.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00085.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00086.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00087.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00088.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00089.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00090.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00091.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00092.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00093.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00094.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00095.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00096.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00097.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00098.wav
#   inflating: kaggle_data/Data/genres_original/classical/classical.00099.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00000.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00001.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00002.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00003.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00004.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00005.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00006.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00007.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00008.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00009.wav
#   inflating: kaggle_data/Data/genres_original/country/country.00010.wav
#   inflating: kaggle_data/Data/genres_original/country/country.
#   inflating: kaggle_data/Data/images_original/rock/rock00091.png
#   inflating: kaggle_data/Data/images_original/rock/rock00092.png
#   inflating: kaggle_data/Data/images_original/rock/rock00093.png
#   inflating: kaggle_data/Data/images_original/rock/rock00094.png
#   inflating: kaggle_data/Data/images_original/rock/rock00095.png
#   inflating: kaggle_data/Data/images_original/rock/rock00096.png
#   inflating: kaggle_data/Data/images_original/rock/rock00097.png
#   inflating: kaggle_data/Data/images_original/rock/rock00098.png
#   inflating: kaggle_data/Data/images_original/rock/rock00099.png

# %%
audio_fp = '/content/kaggle_data/Data/genres_original/classical/classical.00006.wav'
audio_data, sr = librosa.load(audio_fp)
audio_data, _ = librosa.effects.trim(audio_data)

# %%
# plot sample file
plt.figure(figsize=(8,5))
librosa.display.waveshow(audio_data, sr=sr)
plt.show()

# %%
# Default FFT window size
n_fft = 2048 # window size
hop_length = 512 # window hop length for STFT

stft = librosa.stft(audio_data, n_fft=n_fft, hop_length=hop_length)
stft_db = librosa.amplitude_to_db(stft, ref=np.max)

plt.figure(figsize=(6,4))
lplt.specshow(stft, sr=sr, x_axis='time', y_axis='log')
plt.xlabel('Time', fontsize=14)
plt.ylabel('Frequency (Hz)', fontsize=14)
plt.colorbar()
plt.title("Spectrogram With Amplitude")
plt.show()

plt.figure(figsize=(6,4))
lplt.specshow(stft_db, sr=sr, x_axis='time', y_axis='log', cmap='rainbow')
plt.xlabel('Time', fontsize=14)
plt.ylabel('Frequency (Hz)', fontsize=14)
plt.colorbar()
plt.title("Spectrogram With Decibel")
plt.show()

# %%
# plot zoomed audio wave
start = 1000
end = 1200
plt.figure(figsize=(16,4))
plt.plot(audio_data[start:end])
plt.show()

# %%
mel_spec = librosa.feature.melspectrogram(y=audio_data, sr=sr)
mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
plt.figure(figsize=(6, 4))
lplt.specshow(mel_spec_db, sr=sr, hop_length=hop_length, x_axis='time', y_axis='log', cmap='rainbow')
plt.xlabel('Time', fontsize=14)
plt.ylabel('Frequency (Hz)', fontsize=14)
plt.colorbar()
plt.title("Melody Spectrogram")
plt.show()

# %%
chroma = librosa.feature.chroma_stft(y=audio_data, sr=sr)
plt.figure(figsize=(6, 4))
lplt.specshow(chroma, sr=sr, x_axis='time', y_axis='chroma', cmap='rainbow')
plt.colorbar()
plt.title("Chroma Features")
plt.show()

# %%
def make_mel_spectrogram_df(directory, max_per_genre=50):
    '''
    This function takes in a directory of audio files in .wav format, computes the
    mel spectrogram for each audio file, reshapes them so that they are all the
    same size, flattens them, and stores them in a dataframe.

    Genre labels are also computed and added to the dataframe.

    Parameters:
    directory (str): a directory containing audio files in .wav format

    Returns:
    df (DataFrame): a dataframe of flattened mel spectrograms and their
    corresponding genre labels
    '''

    # Creating empty lists for mel spectrograms and labels
    labels = []
    mel_specs = []

    # Looping through each file in the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for dir in dirs:
            count = 0  # Initialize a counter for the files in this subdirectory
            dir_path = os.path.join(root, dir)

            for file in os.listdir(dir_path):
                if count >= max_per_genre:
                    break  # Stop reading more files in this directory if we've read 10
                if file.endswith(".wav"):
                    # print("file:", file)
                    count += 1  # Increment the counter for each .wav file
                    audio_path = os.path.join(dir_path, file)

                    try:
                        # Loading in the audio file
                        y, sr = librosa.load(audio_path)

                        # Extracting the label and adding it to the list
                        label = dir
                        labels.append(label)

                        # Computing the mel spectrograms
                        spect = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=1024)
                        spect = librosa.power_to_db(spect, ref=np.max)

                        # Adjusting the size to be 128 x 660
                        if spect.shape[1] != 660:
                            spect.resize(128, 660, refcheck=False)
                        # Flattening to fit into dataframe and adding to the list
                        spect = spect.flatten()
                        mel_specs.append(spect)
                    except Exception as e:
                        print(f"Error processing {audio_path}: {str(e)}")

    # Converting the lists to arrays so we can stack them
    mel_specs = np.array(mel_specs)
    labels = np.array(labels).reshape(len(labels), 1)

    # Create dataframe
    df = pd.DataFrame(np.hstack((mel_specs, labels)), columns=[f"feature_{i}" for i in range(128*660)] + ["label"])

    return df

# %%
def make_custom_spectrogram_df(directory, max_per_genre=50, n_fft=2048, hop_length=512):

    # Creating empty lists for custom spectrograms and labels
    labels = []
    custom_specs_db = []

    # Looping through each file in the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for dir in dirs:
            count = 0  # Initialize a counter for the files in this subdirectory
            dir_path = os.path.join(root, dir)

            for file in os.listdir(dir_path):
                if count >= max_per_genre:
                    break  # Stop reading more files in this directory if we've read max_per_genre
                if file.endswith(".wav"):
                    # Increment the counter for each .wav file
                    count += 1
                    audio_path = os.path.join(dir_path, file)

                    try:
                        # Loading in the audio file
                        y, sr = librosa.load(audio_path)

                        # Extracting the label and adding it to the list
                        label = dir
                        labels.append(label)

                        # Computing the custom spectrogram with decibels
                        spec = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
                        spec_db = librosa.amplitude_to_db(np.abs(spec), ref=np.max)

                        # Adjusting the size to be 128 x 660
                        if spec_db.shape[1] != 660:
                            spec_db.resize(128, 660, refcheck=False)
                        # Flattening to fit into dataframe and adding to the list
                        spec_flat = spec_db.flatten()
                        custom_specs_db.append(spec_flat)
                    except Exception as e:
                        print(f"Error processing {audio_path}: {str(e)}")

    # Converting the lists to arrays so we can stack them
    custom_specs_db = np.array(custom_specs_db)
    labels = np.array(labels).reshape(len(labels), 1)

    # Create dataframe
    df = pd.DataFrame(np.hstack((custom_specs_db, labels)), columns=[f"feature_{i}" for i in range(128*660)] + ["label"])
    return df

# %%
def make_chroma_feature_df(directory, max_per_genre=50):
    '''
    This function takes in a directory of audio files in .wav format, computes the
    chroma features for each audio file, reshapes them so that they are all the
    same size, flattens them, and stores them in a dataframe.

    Genre labels are also computed and added to the dataframe.

    Parameters:
    directory (str): a directory containing audio files in .wav format

    Returns:
    df (DataFrame): a dataframe of flattened chroma features and their
    corresponding genre labels
    '''

    # Creating empty lists for chroma features and labels
    labels = []
    chroma_features = []

    # Looping through each file in the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for dir in dirs:
            count = 0  # Initialize a counter for the files in this subdirectory
            dir_path = os.path.join(root, dir)

            for file in os.listdir(dir_path):
                if count >= max_per_genre:
                    break  # Stop reading more files in this directory if we've read max_per_genre
                if file.endswith(".wav"):
                    count += 1  # Increment the counter for each .wav file
                    audio_path = os.path.join(dir_path, file)

                    try:
                        # Loading in the audio file
                        y, sr = librosa.load(audio_path)

                        # Extracting the label and adding it to the list
                        label = dir
                        labels.append(label)

                        # Computing the chroma features
                        chroma = librosa.feature.chroma_stft(y=y, sr=sr, n_fft=2048, hop_length=1024)

                        # Adjusting the size to be 12 x 660 (standard chroma feature size)
                        if chroma.shape[1] != 660:
                            chroma.resize(12, 660, refcheck=False)

                        # Flattening to fit into the dataframe and adding to the list
                        chroma = chroma.flatten()
                        chroma_features.append(chroma)
                    except Exception as e:
                        print(f"Error processing {audio_path}: {str(e)}")

    # Converting the lists to arrays so we can stack them
    chroma_features = np.array(chroma_features)
    labels = np.array(labels).reshape(len(labels), 1)

    # Create dataframe
    df = pd.DataFrame(np.hstack((chroma_features, labels)), columns=[f"feature_{i}" for i in range(12*660)] + ["label"])

    return df

# %%
datatype = 2

# %%
# # Using the above function to create a dataframe with all of the flattened mel spectrograms and genre labels
if datatype == 0:
  df = make_mel_spectrogram_df('/content/kaggle_data/Data/genres_original', max_per_genre=95)
if datatype == 1:
  df = make_chroma_feature_df('/content/kaggle_data/Data/genres_original', max_per_genre=95)
if datatype == 2:
  df = make_custom_spectrogram_df('/content/kaggle_data/Data/genres_original', max_per_genre=95)
# Out:
# Error processing /content/kaggle_data/Data/genres_original/jazz/jazz.00054.wav:

# %%
# Mapping the labels to numeric values
label_map = {
    'blues': 1,
    'classical': 2,
    'country': 3,
    'disco': 4,
    'hiphop': 5,
    'jazz': 6,
    'metal': 7,
    'pop': 8,
    'reggae': 9,
    'rock': 10
}

df['y'] = df['label'].map(label_map)

# %%
if datatype == 0:
  df.to_csv('/content/kaggle_data/Data/genre_mel_specs_clean.csv', index=False)
if datatype == 1:
  df.to_csv('/content/kaggle_data/Data/genre_custom_specs_clean.csv', index=False)
if datatype == 2:
  df.to_csv('/content/kaggle_data/Data/genre_chroma_features_clean.csv', index=False)

# %%
# df = pd.read_csv('/content/kaggle_data/Data/genre_mel_specs_clean.csv')

# %%
def get_genre_subset(data, genre_subset):
    '''
    This function takes in a dataframe and a list of genres and returns a new dataframe only including
    the genres in the given list. Its index is reset and new labels are created so that the labels are 0
    through one less than the number of genres.
    '''

    # Filtering the dataframe for the subset of the genres and resetting the index
    df = data.loc[data['label'].isin(genre_subset)]
    df = df.reset_index().drop(columns=['index'])

    # Creating a new label dictionary
    new_label_dict = {}
    for i in range(len(genre_subset)):
        new_label_dict[genre_subset[i]] = i

    # Changing labels to be the new labels
    df['y'] = df['label'].map(new_label_dict)

    return df

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

def preprocess_spec_data(data, genre_subset, max_per_genre=60):
    '''
    This function takes in a dataframe of audio files and a list of genres,
    calls the function get_genre_subset to get a dataframe including only the given genres,
    and completes all of the data preprocessing steps needed to run a neural network.

    Preprecessing steps include:
    1. Reshaping the mel spectrograms to their original form (128 x 660)
    2. Defining the array of targets
    3. Train test split
    4. Standardizing the data
    5. Reshaping the data to be 128 x 660 x 1, where the 1 represents a single color channel
    6. One-hot-encoding target data

    Parameters:
    data (DataFrame): a dataframe of audio files, flattened mel spectrograms, and genre labels
    genre_subset (list): a list of genres included in the dataframe

    Returns:
    X_train (array): training set of features
    X_test (array): testing set of features
    y_train (array): training set of targets
    y_test (array): testing set of targets
    '''

    # Getting a subset of the genres using our genre_subset function
    subset = get_genre_subset(data, genre_subset)

    # Dropping label columns to prepare our feature vector
    specs = subset.drop(columns=['label', 'y'])

    # Reshaping the arrays to their original "image" form
    X = []
    for i in range(len(genre_subset) * max_per_genre - 1):
        X.append(np.array(specs.iloc[i]).reshape(128,660))

    # Converting list X to an array
    X = np.array(X)

    # Defining our targets
    y = subset.loc[subset['label'].isin(genre_subset), 'y'].values

    # train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=.2)

    # Scaling our data to be between 0 and 1

    X_train = X_train.astype(float)
    X_test = X_test.astype(float)

    X_train /= -80
    X_test /= -80

    # Reshaping images to be 128 x 660 x 1
    X_train = X_train.reshape(X_train.shape[0], 128, 660, 1)
    X_test = X_test.reshape(X_test.shape[0], 128, 660, 1)

    # One hot encoding our labels
    y_train = to_categorical(y_train, len(genre_subset))
    y_test = to_categorical(y_test, len(genre_subset))

    return X_train, X_test, y_train, y_test

# %%
def preprocess_chroma_data(data, genre_subset, max_per_genre=60):
    '''
    This function takes in a dataframe of audio files and a list of genres,
    calls the function get_genre_subset to get a dataframe including only the given genres,
    and completes all of the data preprocessing steps needed to run a neural network.

    Preprocessing steps include:
    1. Reshaping the chroma features to their original form
    2. Defining the array of targets
    3. Train-test split
    4. Standardizing the data
    5. Reshaping the data to be 128 x 60 x 1, where the 1 represents a single color channel
    6. One-hot-encoding target data

    Parameters:
    data (DataFrame): a dataframe of audio files, flattened chroma features, and genre labels
    genre_subset (list): a list of genres included in the dataframe

    Returns:
    X_train (array): training set of features
    X_test (array): testing set of features
    y_train (array): training set of targets
    y_test (array): testing set of targets
    '''

    # Getting a subset of the genres using our genre_subset function
    subset = get_genre_subset(data, genre_subset)

    # Dropping label columns to prepare our feature vector
    chroma_features = subset.drop(columns=['label', 'y'])

    # Reshaping the arrays to their original "image" form
    X = []
    for i in range(len(genre_subset) * max_per_genre - 1):
      X.append(np.array(chroma_features.iloc[i]).reshape(132, 60))

    # Converting list X to an array
    X = np.array(X)

    # Defining our targets
    y = subset.loc[subset['label'].isin(genre_subset), 'y'].values

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y, test_size=0.2)

    # Scaling our data (assuming chroma features are in the range [0, 1])
    X_train = X_train.astype(float)
    X_test = X_test.astype(float)

    # Reshaping images to be 128 x 60 x 1
    X_train = X_train.reshape(X_train.shape[0], 132, 60, 1)
    X_test = X_test.reshape(X_test.shape[0], 132, 60, 1)

    # One-hot encoding our labels
    y_train = to_categorical(y_train, len(genre_subset))
    y_test = to_categorical(y_test, len(genre_subset))

    return X_train, X_test, y_train, y_test

# %%
# List of all the genres
genre_list = [
    'jazz',
    'reggae',
    'rock',
    'blues',
    'hiphop',
    'country',
    'metal',
    'classical',
    'disco',
    'pop'
]

# %%
# List of a subset of the genres

# genre_subset = [
#     'jazz',
#     'hiphop',
#     'country',
#     'metal',
#     'classical',
#     'disco',
#     'pop'
# ]

genre_subset = genre_list

# %%
# Using our function to get our features and targets

if datatype in [0, 2]:
  X_train, X_test, y_train, y_test = preprocess_spec_data(df, genre_subset, max_per_genre=95)

if datatype == 1:
  X_train, X_test, y_train, y_test = preprocess_chroma_data(df, genre_subset, max_per_genre=95)

# %%
print(f"Train set has {X_train.shape[0]} records")
print(f"Test set has {X_test.shape[0]} records")
# Out:
# Train set has 759 records
# Test set has 190 records

# %%
datatype
# Out:
# 2

# %%
import tensorflow as tf
print("TF version:-", tf.__version__)
import keras as k


np.random.seed(23456)

# Initiating an empty neural network
cnn_model = k.models.Sequential(name='cnn_1')

if datatype in [0, 2]:
  # Adding convolutional layer
  cnn_model.add(k.layers.Conv2D(filters=16,
                      kernel_size=(3,3),
                      activation='relu',
                      input_shape=(128,660,1)
                      ))

if datatype == 1:
  cnn_model.add(k.layers.Conv2D(filters=16,
                    kernel_size=(3,3),
                    activation='relu',
                    input_shape=(132,60,1)
                    ))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=(2,2)))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=16,
                     kernel_size=(3,3),
                     activation='relu'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=(2,2)))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=32,
                     kernel_size=(3,3),
                     activation='relu'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=(2,2)))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=64,
                     kernel_size=(3,3),
                     activation='relu'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=(2,2)))


# # Adding a flattened layer to input our image data
cnn_model.add(k.layers.Flatten())

# Adding a dense layer
cnn_model.add(k.layers.Dense(1024, activation='relu'))

# Adding a dropout layer for regularization
cnn_model.add(k.layers.Dropout(0.25))

# Adding an output layer
cnn_model.add(k.layers.Dense(10, activation='softmax'))

# Compiling our neural network
cnn_model.compile(loss='categorical_crossentropy',
                  # optimizer='adam',
                  optimizer=k.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])

early_stopping = k.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Fitting our neural network
history = cnn_model.fit(X_train,
                        y_train,
                        batch_size=16,
                        validation_data=(X_test, y_test),
                        epochs=100,
                        callbacks=[early_stopping])
# Out:
# TF version:- 2.14.0
# Epoch 1/100
# 48/48 [==============================] - 14s 39ms/step - loss: 2.3738 - accuracy: 0.1357 - val_loss: 2.1642 - val_accuracy: 0.2211
# Epoch 2/100
# 48/48 [==============================] - 1s 22ms/step - loss: 2.1561 - accuracy: 0.1989 - val_loss: 2.0003 - val_accuracy: 0.3421
# Epoch 3/100
# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get the prediction results of the best model
best_model_predictions = cnn_model.predict(X_test)

# Converts probabilities to category labels
best_model_predictions_classes = np.argmax(best_model_predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Compute the confusion matrix
cm_best_model = confusion_matrix(true_classes, best_model_predictions_classes)

# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_best_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['blues',  'classical',  'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',  'reggae', 'rock'],
            yticklabels=['blues',  'classical',  'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',  'reggae', 'rock'])
plt.xlabel('Predicted', fontsize=16)
plt.ylabel('Actual', fontsize=16)
plt.title('Confusion Matrix - Best Model', fontsize=20)
plt.show()
# Out:
# 6/6 [==============================] - 0s 12ms/step

# %%
best_val_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

best_epoch = best_val_accuracy_index + 1  # Adding 1 because epochs are 1-indexed

# Print the highest val_accuracy and its corresponding epoch
print(f"Highest validation accuracy: {max(history.history['val_accuracy'])} at epoch {best_epoch}")
# Out:
# Highest validation accuracy: 0.4736842215061188 at epoch 14

# %%
# Check out the train loss and test loss over epochs
train_loss = history.history['loss']
test_loss = history.history['val_loss']

# Set figure size.
plt.figure(figsize=(6, 4))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(test_loss, label='Testing Loss', color='red')

# Set title
plt.title('Training and Testing Loss by Epoch', fontsize = 20)
plt.xlabel('Epoch', fontsize = 16)
plt.ylabel('Categorical Crossentropy', fontsize = 16)
# plt.xticks(range(1,100), range(1,100))

plt.legend(fontsize = 16)

# %%
# Checking the model summary
cnn_model.summary()
# Out:
# Model: "cnn_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 658, 16)      160
#
#  max_pooling2d (MaxPooling2  (None, 63, 329, 16)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 327, 16)       2320
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 163, 16)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 161, 32)       4640
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 80, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 78, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 39, 64)         0
#  g2D)
#
#  flatten (Flatten)           (None, 14976)             0
#
#  dense (Dense)               (None, 1024)              15336448
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 15372314 (58.64 MB)
# Trainable params: 15372314 (58.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Try Tanh Activation

# %%
import tensorflow as tf
print("TF version:-", tf.__version__)
import keras as k


np.random.seed(23456)

# Initiating an empty neural network
cnn_model = k.models.Sequential(name='cnn_1')

if datatype in [0, 2]:
  # Adding convolutional layer
  cnn_model.add(k.layers.Conv2D(filters=16,
                      kernel_size=(3,3),
                      activation='tanh',
                      input_shape=(128,660,1)
                      ))
  pool_size = (2, 4)

if datatype == 1:
  cnn_model.add(k.layers.Conv2D(filters=16,
                    kernel_size=(3,3),
                    activation='tanh',
                    input_shape=(132,60,1)
                    ))
  pool_size = (2, 2)

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=pool_size))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=16,
                     kernel_size=(3,3),
                     activation='tanh'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=pool_size))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=32,
                     kernel_size=(3,3),
                     activation='tanh'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=pool_size))

# Adding convolutional layer
cnn_model.add(k.layers.Conv2D(filters=64,
                     kernel_size=(3,3),
                     activation='tanh'))

# Adding max pooling layer
cnn_model.add(k.layers.MaxPooling2D(pool_size=pool_size))


# # Adding a flattened layer to input our image data
cnn_model.add(k.layers.Flatten())


# Adding a dense layer
cnn_model.add(k.layers.Dense(1024, activation='tanh'))

# Adding a dropout layer for regularization
cnn_model.add(k.layers.Dropout(0.25))

# Adding an output layer
cnn_model.add(k.layers.Dense(10, activation='softmax'))

# Compiling our neural network
cnn_model.compile(loss='categorical_crossentropy',
                  # optimizer='adam',
                  optimizer=k.optimizers.Adam(learning_rate=0.001),
                  metrics=['accuracy'])

early_stopping = k.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Fitting our neural network
history = cnn_model.fit(X_train,
                        y_train,
                        batch_size=16,
                        validation_data=(X_test, y_test),
                        epochs=100,
                        callbacks=[early_stopping])
# Out:
# TF version:- 2.14.0
# Epoch 1/100
# 48/48 [==============================] - 3s 29ms/step - loss: 2.2970 - accuracy: 0.1370 - val_loss: 2.1236 - val_accuracy: 0.1789
# Epoch 2/100
# 48/48 [==============================] - 1s 16ms/step - loss: 2.1341 - accuracy: 0.1989 - val_loss: 2.0144 - val_accuracy: 0.2105
# Epoch 3/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.9433 - accuracy: 0.2885 - val_loss: 2.0170 - val_accuracy: 0.2579
# Epoch 4/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.8066 - accuracy: 0.3294 - val_loss: 1.7145 - val_accuracy: 0.3789
# Epoch 5/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.7252 - accuracy: 0.4058 - val_loss: 1.5691 - val_accuracy: 0.4526
# Epoch 6/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.5628 - accuracy: 0.4269 - val_loss: 1.5682 - val_accuracy: 0.4158
# Epoch 7/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.4931 - accuracy: 0.4611 - val_loss: 1.4957 - val_accuracy: 0.4579
# Epoch 8/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.3450 - accuracy: 0.5204 - val_loss: 1.4786 - val_accuracy: 0.4684
# Epoch 9/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.2306 - accuracy: 0.5560 - val_loss: 1.6115 - val_accuracy: 0.4842
# Epoch 10/100
# 48/48 [==============================] - 1s 16ms/step - loss: 1.1451 - accuracy: 0.5903 - val_loss: 1.4852 - val_accuracy: 0.4526
# Epoch 11/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.9471 - accuracy: 0.6667 - val_loss: 1.5884 - val_accuracy: 0.4579
# Epoch 12/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.8462 - accuracy: 0.6983 - val_loss: 1.5933 - val_accuracy: 0.4632
# Epoch 13/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.6690 - accuracy: 0.7813 - val_loss: 1.5471 - val_accuracy: 0.4947
# Epoch 14/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.5605 - accuracy: 0.8261 - val_loss: 1.7552 - val_accuracy: 0.4421
# Epoch 15/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.4173 - accuracy: 0.8722 - val_loss: 1.8160 - val_accuracy: 0.5053
# Epoch 16/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.2238 - accuracy: 0.9578 - val_loss: 1.9782 - val_accuracy: 0.4579
# Epoch 17/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.1456 - accuracy: 0.9631 - val_loss: 2.0496 - val_accuracy: 0.4737
# Epoch 18/100
# 48/48 [==============================] - 1s 16ms/step - loss: 0.1633 - accuracy: 0.9578 - val_loss: 2.2390 - val_accuracy: 0.4579

# %%
# Get the prediction results of the best model
best_model_predictions = cnn_model.predict(X_test)

# Converts probabilities to category labels
best_model_predictions_classes = np.argmax(best_model_predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Compute confusion matrix
cm_best_model = confusion_matrix(true_classes, best_model_predictions_classes)

# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm_best_model, annot=True, fmt='d', cmap='Blues',
            xticklabels=['blues',  'classical',  'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',  'reggae', 'rock'],
            yticklabels=['blues',  'classical',  'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop',  'reggae', 'rock'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Best Model')
plt.show()
# Out:
# 6/6 [==============================] - 0s 39ms/step

# %%
best_val_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

best_epoch = best_val_accuracy_index + 1  # Adding 1 because epochs are 1-indexed

# Print the highest val_accuracy and its corresponding epoch
print(f"Highest validation accuracy: {max(history.history['val_accuracy'])} at epoch {best_epoch}")
# Out:
# Highest validation accuracy: 0.5052631497383118 at epoch 15

# %%
# The code in this cell was adapted from a lecture at General Assembly

# Check out our train loss and test loss over epochs.
train_loss = history.history['loss']
test_loss = history.history['val_loss']

# Set figure size.
plt.figure(figsize=(6, 4))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_loss, label='Training Loss', color='blue')
plt.plot(test_loss, label='Testing Loss', color='red')

# Set title
plt.title('Training and Testing Loss by Epoch', fontsize = 25)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
# plt.xticks(range(1,100), range(1,100))

plt.legend(fontsize = 18)

# %%
# Checking the model summary
cnn_model.summary()
# Out:
# Model: "cnn_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 658, 16)      160
#
#  max_pooling2d_4 (MaxPoolin  (None, 63, 164, 16)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 162, 16)       2320
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 40, 16)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 38, 32)        4640
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 9, 32)         0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 7, 64)         18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 1, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 384)               0
#
#  dense_2 (Dense)             (None, 1024)              394240
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 430106 (1.64 MB)
# Trainable params: 430106 (1.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
